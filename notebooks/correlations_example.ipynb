# %%
# Import and run the correlation script programmatically
from scripts.compute_correlations import run
from pathlib import Path
out = run(Path('clinical.csv'), Path('outputs/correlations'), prefix='clinical')
out

# %%
# Display the saved heatmaps and the top rows of the CSVs
from IPython.display import Image, display
import pandas as pd
display(Image('outputs/correlations/clinical_pearson.png'))
display(Image('outputs/correlations/clinical_spearman.png'))
print('Pearson head:')
display(pd.read_csv('outputs/correlations/clinical_pearson.csv').head())
print('Spearman head:')
display(pd.read_csv('outputs/correlations/clinical_spearman.csv').head())
